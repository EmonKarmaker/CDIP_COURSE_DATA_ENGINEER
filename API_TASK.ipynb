# %%
import requests
import pandas as pd

api_url = 'https://api.football-data.org/v4/competitions/'

response = requests.get(api_url)
result_json = response.json()
result_json
result_json.keys()
for data in result_json['competitions']:
  if data['currentSeason'] is None:
    print(data)

data_list = []
for data in result_json['competitions']:

  temp = {
  'Region'    : data['area']['name'],
  'Name'      : data['name'] ,
  'Type'      : data['type'],
  'Start Date': data['currentSeason'] if data['currentSeason'] is None else data['currentSeason']['startDate'],
  'End Date'  : data['currentSeason'] if data['currentSeason'] is None else data['currentSeason']['endDate']
  }

  data_list.append(temp)

  df = pd.DataFrame(data_list)
  date_to_month = {
    "01" : 'Jan',
    "02" : 'Feb',
    "03" : 'Mar',
    "04" : 'Apr',
    "05" : 'May',
    "06" : 'Jun',
    "07" : 'Jul',
    "08" : 'Aug',
    "09" : 'Sep',
    "10" : 'Oct',
    "11" : 'Nov',
    "12" : 'Dec'
}

def get_timeline(start,end):
  return  None if(start is None or end is None) else f"{date_to_month[start.split('-')[1]]} - {date_to_month[end.split('-')[1]]}"

def get_timeline(start,end):
  return  None if(start is None or end is None) else f"{date_to_month[start.split('-')[1]]} - {date_to_month[end.split('-')[1]]}"
df
# Out:
# {'id': 2161, 'area': {'id': 2108, 'name': 'India', 'code': 'IND', 'flag': None}, 'name': 'Indian Super League', 'code': 'ISL', 'type': 'LEAGUE', 'emblem': None, 'plan': 'TIER_FOUR', 'currentSeason': None, 'numberOfAvailableSeasons': 0, 'lastUpdated': '2022-07-26T11:21:45Z'}
#         Region                       Name      Type  Start Date    End Date
# 0       Africa                 Africa Cup       CUP  2024-01-13  2024-01-24
# 1       Africa       WC Qualification CAF       CUP  2023-11-15  2025-10-13
# 2       Africa       AFC Champions League       CUP  2022-04-06  2023-05-05
# 3    Argentina         Primera B Nacional    LEAGUE  2021-03-13  2021-12-26
# 4    Argentina           Liga Profesional    LEAGUE  2024-05-12  2024-12-15
# ..         ...                        ...       ...         ...         ...
# 178      World            Club Friendlies  PLAYOFFS  2024-01-05  2024-08-10
# 179      World             FIFA World Cup       CUP  2022-11-20  2022-12-18
# ...
